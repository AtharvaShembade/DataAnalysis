# %%
import pandas as  pd
import seaborn as sb

# %%
df = pd.read_csv('train.csv')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sb.distplot(df['Age'],kde=True,bins=40)

# %%
sb.distplot(df['Pclass'],kde=True,bins=10)

# %%
sb.jointplot(data=df,x='Age',y='Fare',kind='reg')

# %%
sb.pairplot(data=df,hue='Survived',diag_kind='hist')

# %%
sb.barplot(data = df ,x='Pclass' ,y='Age')

# %%
sb.countplot(data=df , x='Pclass', hue='Sex')

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
sb.boxplot(data=df, x='Age')

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#(Q1 - 1.5IQR, Q3  + 1.5IQR)          #anything before -7 and after 65 are outliers
20-27,38+27
# Out:
# (-7, 65)
