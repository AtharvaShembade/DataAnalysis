# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot((1,2,3,4,5),(9,8,17,25,33),marker='o',c='red',lw='5',alpha=0.1)
plt.xlabel('Xaxis')
plt.ylabel('Yaxis')
plt.title('graph')
# Out:
# Text(0.5, 1.0, 'graph')

# %%
m = np.random.randint(1,100,(20,2))

# %%
m
# Out:
# array([[36,  4],
#        [65, 42],
#        [71, 66],
#        [53, 11],
#        [40, 56],
#        [96, 89],
#        [56,  7],
#        [99, 97],
#        [29, 12],
#        [86, 95],
#        [40, 49],
#        [59, 56],
#        [ 1, 59],
#        [98, 47],
#        [43, 46],
#        [45, 34],
#        [70, 90],
#        [85, 54],
#        [ 4, 24],
#        [31, 78]])

# %%
plt.plot(m[:,0],m[:,1],marker='x') #values not sorted so random graph

# %%
plt.scatter(m[:,0],m[:,1],c='red',s=60)

# %%
c = np.random.randint(1,200,(50,3))   #50 cities first two are coord third column in cases,cases b/w 1 and 200

# %%
c
# Out:
# array([[ 94, 147, 148],
#        [176, 182,  20],
#        [ 60, 175, 134],
#        [ 79,  57,  86],
#        [ 56, 192, 107],
#        [122, 122, 119],
#        [ 19, 104, 124],
#        [165, 124, 175],
#        [132,  20, 140],
#        [ 52, 145, 198],
#        [  3,  87,  77],
#        [ 30, 177, 105],
#        [ 17, 130, 147],
#        [117, 177, 100],
#        [ 69,  55,  63],
#        [174,  51, 153],
#        [  5,  40, 166],
#        [ 18,  20,  99],
#        [169, 155,   3],
#        [108, 171,   4],
#        [ 73, 187, 174],
#        [ 27, 105,   8],
#        [121,  33,  21],
#        [129,  43, 130],
#        [170, 154, 197],
#        [ 61, 146,  88],
#        [180,  44,  50],
#        [ 78,  45,  83],
#        [164, 131,  31],
#        [165, 139,  33],
#        [185, 161,  15],
#        [ 39,  47,  93],
#        [197, 133, 126],
#        [ 98, 108,  78],
#        [ 26,  28, 114],
#        [  3, 108,  19],
#        [130,  70, 106],
#        [190, 104,  87],
# ...

# %%
plt.scatter(c[:,0],c[:,1],s=c[:,2],alpha=0.4)

# %%
x=np.arange(1,12.56,0.1)                    #second no acc to radian not degree
y=np.sin(x)

# %%
plt.plot(x,y,c='red')

# %%
plt.scatter(x,y)
plt.scatter(x,np.cos(x))
